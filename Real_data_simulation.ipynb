# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from scipy import interpolate
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from numpy import asarray
from numpy import save


df = pd.read_csv (r'/home/stefan/Desktop/ML_Project/Meteto_data/animaciya4/Flow_table_3 (copy).csv') 
# ^ Чете файла с данните от метео-станции. Трябва да се промени пътя за да намиря файла.






x = np.array([df.iloc[1]['Burgas'],    #Прави арей с геог. ширина на метео-станциите
              df.iloc[1]['Nos Emine'],
              df.iloc[1]['Varna'],
              df.iloc[1]['Tyulenovo'],
              df.iloc[1]['Mangalia'],
              df.iloc[1]['Silistra'],
              df.iloc[1]['Rousse'],
              df.iloc[1]['Sistov'],
              df.iloc[1]['Corabia'],
              df.iloc[1]['Lom'],
              df.iloc[1]['Negotin'],
              df.iloc[1]['Zajecar'],
              df.iloc[1]['Dimitrovgrad'],
              df.iloc[1]['Strezimirovci'],
              df.iloc[1]['Gyueshevo'],
              df.iloc[1]['Petrich'],
              df.iloc[1]['Dospat'],
              df.iloc[1]['Smolyan'],
              df.iloc[1]['Tihomir'],
              df.iloc[1]['Ivaylovgrad'],
              df.iloc[1]['Svilengrad'],
              df.iloc[1]['Malko Tarnovo'],
              df.iloc[1]['Rezovo'],
              df.iloc[1]['Bansko'],
              df.iloc[1]['Plovdiv'],
              df.iloc[1]['Yambol'],
              df.iloc[1]['Shumen'],
              df.iloc[1]['Veliko Tarnovo'],
              df.iloc[1]['Sofia'],
              df.iloc[1]['Pleven']])       

y = np.array([df.iloc[0]['Burgas'],    #Прави арей с геог. дължина на метео-станциите
              df.iloc[0]['Nos Emine'],
              df.iloc[0]['Varna'],
              df.iloc[0]['Tyulenovo'],
              df.iloc[0]['Mangalia'],
              df.iloc[0]['Silistra'],
              df.iloc[0]['Rousse'],
              df.iloc[0]['Sistov'],
              df.iloc[0]['Corabia'],
              df.iloc[0]['Lom'],
              df.iloc[0]['Negotin'],
              df.iloc[0]['Zajecar'],
              df.iloc[0]['Dimitrovgrad'],
              df.iloc[0]['Strezimirovci'],
              df.iloc[0]['Gyueshevo'],
              df.iloc[0]['Petrich'],
              df.iloc[0]['Dospat'],
              df.iloc[0]['Smolyan'],
              df.iloc[0]['Tihomir'],
              df.iloc[0]['Ivaylovgrad'],
              df.iloc[0]['Svilengrad'],
              df.iloc[0]['Malko Tarnovo'],
              df.iloc[0]['Rezovo'],
              df.iloc[0]['Bansko'],
              df.iloc[0]['Plovdiv'],
              df.iloc[0]['Yambol'],
              df.iloc[0]['Shumen'],
              df.iloc[0]['Veliko Tarnovo'],
              df.iloc[0]['Sofia'],
              df.iloc[0]['Pleven']])    

for i in range(200):
    nt = i # Във файла има 548 стъпки във времето - 548 реда с данни.
    
    magnitude= np.array([df.iloc[11+nt]['Burgas'],    #Прави арей с големината на вятъра км/ч
                         df.iloc[11+nt]['Nos Emine'],
                         df.iloc[11+nt]['Varna'],
                         df.iloc[11+nt]['Tyulenovo'],
                         df.iloc[11+nt]['Mangalia'],
                         df.iloc[11+nt]['Silistra'],
                         df.iloc[11+nt]['Rousse'],
                         df.iloc[11+nt]['Sistov'],
                         df.iloc[11+nt]['Corabia'],
                         df.iloc[11+nt]['Lom'],
                         df.iloc[11+nt]['Negotin'],
                         df.iloc[11+nt]['Zajecar'],
                         df.iloc[11+nt]['Dimitrovgrad'],
                         df.iloc[11+nt]['Strezimirovci'],
                         df.iloc[11+nt]['Gyueshevo'],
                         df.iloc[11+nt]['Petrich'],
                         df.iloc[11+nt]['Dospat'],
                         df.iloc[11+nt]['Smolyan'],
                         df.iloc[11+nt]['Tihomir'],
                         df.iloc[11+nt]['Ivaylovgrad'],
                         df.iloc[11+nt]['Svilengrad'],
                         df.iloc[11+nt]['Malko Tarnovo'],
                         df.iloc[11+nt]['Rezovo'],
                         df.iloc[11+nt]['Bansko'],
                         df.iloc[11+nt]['Plovdiv'],
                         df.iloc[11+nt]['Yambol'],
                         df.iloc[11+nt]['Shumen'],
                         df.iloc[11+nt]['Veliko Tarnovo'],
                         df.iloc[11+nt]['Sofia'],
                         df.iloc[11+nt]['Pleven']])       
    
    
    
    
    
    direction = np.array([df.iloc[11+nt]['Burgas.1'],    #Прави арей с посока на вятъра (градуси)
                          df.iloc[11+nt]['Nos Emine.1'],
                          df.iloc[11+nt]['Varna.1'],
                          df.iloc[11+nt]['Tyulenovo.1'],
                          df.iloc[11+nt]['Mangalia.1'],
                          df.iloc[11+nt]['Silistra.1'],
                          df.iloc[11+nt]['Rousse.1'],
                          df.iloc[11+nt]['Sistov.1'],
                          df.iloc[11+nt]['Corabia.1'],
                          df.iloc[11+nt]['Lom.1'],
                          df.iloc[11+nt]['Negotin.1'],
                          df.iloc[11+nt]['Zajecar.1'],
                          df.iloc[11+nt]['Dimitrovgrad.1'],
                          df.iloc[11+nt]['Strezimirovci.1'],
                          df.iloc[11+nt]['Gyueshevo.1'],
                          df.iloc[11+nt]['Petrich.1'],
                          df.iloc[11+nt]['Dospat.1'],
                          df.iloc[11+nt]['Smolyan.1'],
                          df.iloc[11+nt]['Tihomir.1'],
                          df.iloc[11+nt]['Ivaylovgrad.1'],
                          df.iloc[11+nt]['Svilengrad.1'],
                          df.iloc[11+nt]['Malko Tarnovo.1'],
                          df.iloc[11+nt]['Rezovo.1'],
                          df.iloc[11+nt]['Bansko.1'],
                          df.iloc[11+nt]['Plovdiv.1'],
                          df.iloc[11+nt]['Yambol.1'],
                          df.iloc[11+nt]['Shumen.1'],
                          df.iloc[11+nt]['Veliko Tarnovo.1'],
                          df.iloc[11+nt]['Sofia.1'],
                          df.iloc[11+nt]['Pleven.1']])       
    
    
    
    
    nx=41 
    ny=41
    
    x=x.astype(np.float)
    y=y.astype(np.float)
    
    
    x = np.ceil(((x - x.min())/((x - x.min()).max())*40)) #Преминава от координати към грид
    y = np.ceil(((y - y.min())/((y - y.min()).max())*40)) 
    
    
    
    
    magnitude = magnitude.astype(np.float)
    magnitude = magnitude/magnitude.max()  # Нормира скоростите, така че максималната скорост да е 1
    
    direction = direction.astype(np.float)
    
    u_data = magnitude*np.cos(np.radians(direction)) # Смята u и v за всяка станция 
    v_data = magnitude*np.sin(np.radians(direction))
    
    
    xx = np.linspace(0, nx, nx, False) 
    yy = np.linspace(0, nx, ny, False) 
    
    X, Y = np.meshgrid(xx, yy) 
    
    points = np.transpose(np.vstack((x, y)))
    
    u = interpolate.griddata(points, u_data, (X, Y), method='cubic',fill_value = 1000)
    v = interpolate.griddata(points, v_data, (X, Y), method='cubic',fill_value = 1000)
    

    save('/home/stefan/Desktop/ML_Project/Meteto_data/Speed_values/u'+str(i)+'.npy', u)
    save('/home/stefan/Desktop/ML_Project/Meteto_data/Speed_values/v'+str(i)+'.npy', v)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-906dba5e4936> in <module>
#      85     nt = i # Във файла има 548 стъпки във времето - 548 реда с данни.
#      86
# ---> 87     magnitude= np.array([df.iloc[11+nt]['Burgas'],    #Прави арей с големината на вятъра км/ч
#      88                          df.iloc[11+nt]['Nos Emine'],
#      89                          df.iloc[11+nt]['Varna'],
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2136
#    2137             # validate the location
# ...

# %%
from matplotlib.ticker import AutoMinorLocator
import matplotlib as mpl
from numpy import load
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from scipy import interpolate
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from numpy import asarray
from numpy import save
from scipy.interpolate import UnivariateSpline
from scipy.interpolate import splprep, splev

i=0
i=str(i)
nx=41 
ny=41
   
df = pd.read_csv (r'/home/stefan/Desktop/ML_Project/Meteto_data/animaciya4/Flow_table_3 (copy).csv') 
# ^ Чете файла с данните от метео-станции. Трябва да се промени пътя за да намиря файла.






x = np.array([df.iloc[1]['Burgas'],    #Прави арей с геог. ширина на метео-станциите
              df.iloc[1]['Nos Emine'],
              df.iloc[1]['Varna'],
              df.iloc[1]['Tyulenovo'],
              df.iloc[1]['Mangalia'],
              df.iloc[1]['Silistra'],
              df.iloc[1]['Rousse'],
              df.iloc[1]['Sistov'],
              df.iloc[1]['Corabia'],
              df.iloc[1]['Lom'],
              df.iloc[1]['Negotin'],
              df.iloc[1]['Zajecar'],
              df.iloc[1]['Dimitrovgrad'],
              df.iloc[1]['Strezimirovci'],
              df.iloc[1]['Gyueshevo'],
              df.iloc[1]['Petrich'],
              df.iloc[1]['Dospat'],
              df.iloc[1]['Smolyan'],
              df.iloc[1]['Tihomir'],
              df.iloc[1]['Ivaylovgrad'],
              df.iloc[1]['Svilengrad'],
              df.iloc[1]['Malko Tarnovo'],
              df.iloc[1]['Rezovo'],
              df.iloc[1]['Bansko'],
              df.iloc[1]['Plovdiv'],
              df.iloc[1]['Yambol'],
              df.iloc[1]['Shumen'],
              df.iloc[1]['Veliko Tarnovo'],
              df.iloc[1]['Sofia'],
              df.iloc[1]['Pleven']])       

y = np.array([df.iloc[0]['Burgas'],    #Прави арей с геог. дължина на метео-станциите
              df.iloc[0]['Nos Emine'],
              df.iloc[0]['Varna'],
              df.iloc[0]['Tyulenovo'],
              df.iloc[0]['Mangalia'],
              df.iloc[0]['Silistra'],
              df.iloc[0]['Rousse'],
              df.iloc[0]['Sistov'],
              df.iloc[0]['Corabia'],
              df.iloc[0]['Lom'],
              df.iloc[0]['Negotin'],
              df.iloc[0]['Zajecar'],
              df.iloc[0]['Dimitrovgrad'],
              df.iloc[0]['Strezimirovci'],
              df.iloc[0]['Gyueshevo'],
              df.iloc[0]['Petrich'],
              df.iloc[0]['Dospat'],
              df.iloc[0]['Smolyan'],
              df.iloc[0]['Tihomir'],
              df.iloc[0]['Ivaylovgrad'],
              df.iloc[0]['Svilengrad'],
              df.iloc[0]['Malko Tarnovo'],
              df.iloc[0]['Rezovo'],
              df.iloc[0]['Bansko'],
              df.iloc[0]['Plovdiv'],
              df.iloc[0]['Yambol'],
              df.iloc[0]['Shumen'],
              df.iloc[0]['Veliko Tarnovo'],
              df.iloc[0]['Sofia'],
              df.iloc[0]['Pleven']])    

for nt in range(124):
    
    magnitude= np.array([df.iloc[11+nt]['Burgas'],    #Прави арей с големината на вятъра км/ч
                         df.iloc[11+nt]['Nos Emine'],
                         df.iloc[11+nt]['Varna'],
                         df.iloc[11+nt]['Tyulenovo'],
                         df.iloc[11+nt]['Mangalia'],
                         df.iloc[11+nt]['Silistra'],
                         df.iloc[11+nt]['Rousse'],
                         df.iloc[11+nt]['Sistov'],
                         df.iloc[11+nt]['Corabia'],
                         df.iloc[11+nt]['Lom'],
                         df.iloc[11+nt]['Negotin'],
                         df.iloc[11+nt]['Zajecar'],
                         df.iloc[11+nt]['Dimitrovgrad'],
                         df.iloc[11+nt]['Strezimirovci'],
                         df.iloc[11+nt]['Gyueshevo'],
                         df.iloc[11+nt]['Petrich'],
                         df.iloc[11+nt]['Dospat'],
                         df.iloc[11+nt]['Smolyan'],
                         df.iloc[11+nt]['Tihomir'],
                         df.iloc[11+nt]['Ivaylovgrad'],
                         df.iloc[11+nt]['Svilengrad'],
                         df.iloc[11+nt]['Malko Tarnovo'],
                         df.iloc[11+nt]['Rezovo'],
                         df.iloc[11+nt]['Bansko'],
                         df.iloc[11+nt]['Plovdiv'],
                         df.iloc[11+nt]['Yambol'],
                         df.iloc[11+nt]['Shumen'],
                         df.iloc[11+nt]['Veliko Tarnovo'],
                         df.iloc[11+nt]['Sofia'],
                         df.iloc[11+nt]['Pleven']])       
    
    
    
    
    
    direction = np.array([df.iloc[11+nt]['Burgas.1'],    #Прави арей с посока на вятъра (градуси)
                          df.iloc[11+nt]['Nos Emine.1'],
                          df.iloc[11+nt]['Varna.1'],
                          df.iloc[11+nt]['Tyulenovo.1'],
                          df.iloc[11+nt]['Mangalia.1'],
                          df.iloc[11+nt]['Silistra.1'],
                          df.iloc[11+nt]['Rousse.1'],
                          df.iloc[11+nt]['Sistov.1'],
                          df.iloc[11+nt]['Corabia.1'],
                          df.iloc[11+nt]['Lom.1'],
                          df.iloc[11+nt]['Negotin.1'],
                          df.iloc[11+nt]['Zajecar.1'],
                          df.iloc[11+nt]['Dimitrovgrad.1'],
                          df.iloc[11+nt]['Strezimirovci.1'],
                          df.iloc[11+nt]['Gyueshevo.1'],
                          df.iloc[11+nt]['Petrich.1'],
                          df.iloc[11+nt]['Dospat.1'],
                          df.iloc[11+nt]['Smolyan.1'],
                          df.iloc[11+nt]['Tihomir.1'],
                          df.iloc[11+nt]['Ivaylovgrad.1'],
                          df.iloc[11+nt]['Svilengrad.1'],
                          df.iloc[11+nt]['Malko Tarnovo.1'],
                          df.iloc[11+nt]['Rezovo.1'],
                          df.iloc[11+nt]['Bansko.1'],
                          df.iloc[11+nt]['Plovdiv.1'],
                          df.iloc[11+nt]['Yambol.1'],
                          df.iloc[11+nt]['Shumen.1'],
                          df.iloc[11+nt]['Veliko Tarnovo.1'],
                          df.iloc[11+nt]['Sofia.1'],
                          df.iloc[11+nt]['Pleven.1']])       
    
    
    
    
    nx=41
    ny=41
    
    x=x.astype(np.float)
    y=y.astype(np.float)
    
    
    x = np.ceil(((x - x.min())/((x - x.min()).max())*41)) #Преминава от координати към грид
    y = np.ceil(((y - y.min())/((y - y.min()).max())*41)) 
    
    
    
    
    magnitude = magnitude.astype(np.float)
    magnitude = magnitude/magnitude.max()  # Нормира скоростите, така че максималната скорост да е 1
    
    direction = direction.astype(np.float)
    
    u_data = magnitude*np.cos(np.radians(direction)) # Смята u и v за всяка станция 
    v_data = magnitude*np.sin(np.radians(direction))
        
        
        
        
    
    xx = np.linspace(0, nx, 20, False) 
    yy = np.linspace(0, nx, 20, False) 
        
    X, Y = np.meshgrid(xx, yy) 
    
    
    
    xc = np.linspace(0, nx, ny, False) 
    yc = np.linspace(0, nx, ny, False) 
     
    
    XC, YC = np.meshgrid(xc,yc)
    points = np.transpose(np.vstack((x, y)))
    
    u = interpolate.griddata(points, u_data, (X, Y), method='cubic')
    v = interpolate.griddata(points, v_data, (X, Y), method='cubic')
    
    
    uc = interpolate.griddata(points, u_data, (XC, YC), method='cubic')
    vc = interpolate.griddata(points, v_data, (XC, YC), method='cubic')
    
    fig = plt.figure()
    ax = plt.gca()
    
    
    
    z = np.zeros((20, 20))
    z[:]=np.sqrt(pow(u[:],2)+pow(v[:],2))
    
    
    zc = np.zeros((ny, nx))
    zc[:]=np.sqrt(pow(uc[:],2)+pow(vc[:],2))
    
    
    binaryyy = cm.get_cmap('gnuplot2', 512)
    newcmp = ListedColormap(binaryyy(np.linspace(0.2, 0, 256)))
    
    plt.quiver(X, Y, u/z, v/z, pivot='tail')
    #plt.streamplot(X, Y, u, v, color=z, cmap=newcmp, linewidth=z*2,arrowstyle ='->', arrowsize = 1.2)
    
    
    plt.contourf(XC, YC, zc, 30, alpha=0.3, cmap=cm.twilight_shifted)
    
    
#     cbar = plt.colorbar(fraction=0.046, pad=0.04)
#     cbar.ax.set_ylabel('Normalized Wind speed', labelpad=10)
#     #cbar.set_clim(0., 1.)
    
    
    
    
    img = plt.imread("/home/stefan/Desktop/balkans23.png")
    plt.imshow(img, extent=[0,41,0,41], aspect=0.75)
    
    
    #plt.imshow(img, extent=[22.354,28.607,41.236 ,  44.214], aspect=1.5)
    #plt.axis(xmin= 22.2 ,xmax = 28.7,ymin = 41.2 ,ymax =  44.3)
    
    plt.xlabel('x coordinate on the gridworld')
    plt.ylabel('y coordinate on the gridworld')
    
    minor_locator = AutoMinorLocator(5)
    plt.gca().xaxis.set_minor_locator(minor_locator)
    plt.gca().yaxis.set_minor_locator(minor_locator)
    
        #plt.plot(x,y,'o--')
    actions_taken = load('/home/stefan/Desktop/ML_Project/Meteto_data/animaciya5/probagent_Vspeed0.51_actions.npy')
    actions_taken = np.flip(actions_taken,1)
    a, ind = np.unique(actions_taken, axis=0, return_index=True)
    a1 = a[np.argsort(ind)]
    act1x, act1y = zip(*a1[0:35])
    
    
    act1x = np.asarray(act1x)
    act1y = np.asarray(act1y)
    act1x = np.insert(act1x,0,24)
    act1y = np.insert(act1y,0,34)
    
    tck, u = splprep([act1x, act1y], s=5)
    new_points = splev(u, tck)
    plt.plot(new_points[0][0:nt], new_points[1][0:nt], 'r-')
    
    
    
    
        
    actions_taken = load('/home/stefan/Desktop/ML_Project/Meteto_data/animaciya5/probagent_Vspeed0.51_actions_triv4.npy')
    actions_taken = np.flip(actions_taken,1)
    a, ind = np.unique(actions_taken, axis=0, return_index=True)
    a1 = a[np.argsort(ind)]
    act1x, act1y = zip(*a1[0:67])
    
    
    act1x = np.asarray(act1x)
    act1y = np.asarray(act1y)
    act1x = np.insert(act1x,0,24)
    act1y = np.insert(act1y,0,35)
    
    tck, u = splprep([act1x, act1y], s=5)
    new_points = splev(u, tck)
    plt.plot(new_points[0][0:nt], new_points[1][0:nt], 'g-')
        
    plt.axis(xmin=0, xmax=41, ymin=0, ymax=41)
    
    #plt.plot(actX, actY, 'o',linewidth=0.3, c='g')
    
    filename='/home/stefan/Desktop/ML_Project/Meteto_data/animaciya5/Flow_step'+str(nt).zfill(3)+'.png'
    plt.savefig(filename, dpi=300)
    plt.gca()
    fig.clf()    
    fig.clf()
    plt.close()
    
    #plt.grid('both', linestyle='-',linewidth=0.5, which='both')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-f5f529221b47> in <module>
#      93 for nt in range(124):
#      94
# ---> 95     magnitude= np.array([df.iloc[11+nt]['Burgas'],    #Прави арей с големината на вятъра км/ч
#      96                          df.iloc[11+nt]['Nos Emine'],
#      97                          df.iloc[11+nt]['Varna'],
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2136
#    2137             # validate the location
# ...
